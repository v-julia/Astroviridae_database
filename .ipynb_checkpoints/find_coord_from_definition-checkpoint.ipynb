# %%
import csv
from Bio import SeqIO
from Bio.SeqFeature import SeqFeature, FeatureLocation
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
import re

# %% [markdown]
# Вывод id-шников, у которых везде NA-NA

# %%
import pandas as pd
df = pd.read_csv("AV_2_orf.txt")
result = df[(df["1A"] == "NA-NA") & (df["1B"] == "NA-NA") & (df["2"] == "NA-NA")]
id_list = result["id"].tolist()
print(id_list)
pd.DataFrame(id_list, columns=["id"]).to_csv("all_NA_ids.csv", index=False)
# Out:
# ['PX095754', 'PX095696', 'PX113257', 'PX113255', 'PX113254', 'PV793827', 'PV793829', 'PV793828', 'PV793826', 'PV793833', 'PV793831', 'PQ421854', 'PQ421853', 'PQ421852', 'PQ421851', 'PQ421848', 'PQ421847', 'PQ421846', 'PQ421845', 'PQ421844', 'PQ421843', 'PQ421842', 'PQ421841', 'PP211271', 'PP211223', 'PP211222', 'PP211221', 'PG036827', 'PG036826', 'PG036825', 'PG036824', 'PG036823', 'PG036822', 'PG036821', 'PG036820', 'PQ150499', 'PD223317', 'PD223316', 'PD222915', 'PD222914', 'PL092599', 'PL092591', 'PL092587', 'PL092412', 'PL092404', 'PL092400', 'PL092225', 'PL092217', 'PL092213', 'PL190248', 'PQ573797', 'PQ573796', 'PQ161557', 'PQ055527', 'PQ335170', 'PP272729', 'PQ110289', 'PP512783', 'OR951098', 'OR951097', 'OR951096', 'OR951094', 'OR951092', 'OR951091', 'OR951090', 'OR951089', 'OR951088', 'OR951087', 'OR951086', 'OR951083', 'OR951082', 'OR951078', 'OR951077', 'OR951076', 'OR951075', 'OR951074', 'OR951073', 'OR951072', 'OR951070', 'OR951069', 'OR951068', 'OR951067', 'OR951065', 'OR951064', 'OR951063', 'OR951060', 'OR951059', 'OR951058', 'OR951057', 'OR951056', 'OR951055', 'OR951054', 'OR951052', 'OR951050', 'OR951049', 'OR951048', 'OR951047', 'OR951045', 'OR951044', 'OR951043', 'OR951042', 'OR951041', 'OR951040', 'OR951039', 'OR951038', 'OR951036', 'OR951035', 'OR951034', 'OR951033', 'OR951032', 'OR951031', 'OR951030', 'OR951029', 'OR951028', 'OR951027', 'OR951026', 'OR951025', 'OR951024', 'OR951023', 'OR951022', 'OR951021', 'OR951020', 'OR951017', 'OR951016', 'OR951015', 'OR951014', 'OR951013', 'OR951012', 'OR951010', 'OR951009', 'OR951008', 'OR871062', 'OR871061', 'OR871060', 'OR800315', 'OR800314', 'OQ986647', 'OR645486', 'OQ802763', 'OQ802762', 'OQ802761', 'OQ802757', 'OQ802714', 'OR234613', 'OR234607', 'OQ709194', 'OQ709193', 'OQ709192', 'OQ709191', 'OQ709190', 'OQ709189', 'OQ709188', 'OQ599876', 'ON932807', 'OP413956', 'OP413950', 'OP474168', 'OK483336', 'OK483335', 'OM514376', 'MN977118', 'ON304004', 'OM954095', 'OM953853', 'OM953852', 'MW310482', 'MW310480', 'MW310478', 'MW310470', 'MW310467', 'MW310464', 'MW310462', 'OL739531', 'OL739530', 'MW239504', 'MW239381', 'MW239289', 'MW239205', 'MW239195', 'MW239194', 'MT568535', 'MZ476779', 'MZ182272', 'MZ182271', 'MZ375144', 'MZ291967', 'MZ443626', 'MW924358', 'MW924357', 'MW924356', 'MW853972', 'MW645022', 'MW645021', 'MP874225', 'MP874224', 'MP874223', 'MP874222', 'MP874221', 'MP874220', 'MP874219', 'MP874218', 'MW347540', 'MW347048', 'MW346737', 'MT896156', 'MT896155', 'MN841288', 'MN733910', 'NC_040647', 'MN036159', 'MN036131', 'MN035893', 'MN035838', 'MN035574', 'MN035429', 'MN035369', 'MN034849', 'MN034422', 'MN034197', 'MN033907', 'MN033591', 'MN033177', 'MN033141', 'MN032977', 'MK387179', 'MK387178', 'MK387177', 'MH188020', 'MG846413', 'KC411816', 'MF973528', 'MF973527', 'MF973526', 'MF973525', 'MF973524', 'MF973523', 'MF973522', 'MF973521', 'MF973520', 'MF973519', 'MF973518', 'MF973517', 'MF973516', 'MF973515', 'MF973514', 'MF973513', 'MF973512', 'MF973511', 'MF973510', 'MF973509', 'MF973508', 'MF973507', 'MF973506', 'MF973505', 'MF973504', 'MF973503', 'MF973502', 'KY814659', 'KY814658', 'KY814657', 'KY814656', 'KY814655', 'KY814654', 'KY814653', 'KY814652', 'KY814651', 'KY814650', 'KY814649', 'KY814648', 'KY814647', 'KY814646', 'KY814645', 'KY814644', 'KX522573', 'KX522572', 'KX522571', 'KX522570', 'KX522569', 'KX522568', 'KX522567', 'KX522566', 'KU510484', 'KU510483', 'KU510482', 'KU510481', 'KU510480', 'KU510479', 'KU510478', 'KU510477', 'KU510476', 'KU510475', 'KU510474', 'KU510473', 'KU510472', 'KU510471', 'KU510470', 'KU510469', 'KU510468', 'KU510467', 'KU510466', 'KU510465', 'KU510464', 'KU510463', 'KU510462', 'KU510461', 'KU510460', 'KU510459', 'KU510458', 'KU510457', 'KU510456', 'KU510455', 'KU510454', 'KU510453', 'KU510452', 'KU510451', 'KU510450', 'KU510449', 'KU510448', 'KU510447', 'KU510446', 'KU510445', 'KU510444', 'KU510443', 'KU510442', 'KU510441', 'DQ327618', 'DQ327617', 'DQ327616', 'DQ327615', 'DQ327614', 'DQ327613', 'DQ327612', 'DQ327611', 'D ...

# %% [markdown]
# Скрипт поиска слов из 1ab_2_final.csv в definition файла AV_2.gb, результат записываем в extra_genes.csv

# %%
gb_file = "AV_2.gb"
csv_file = "1ab_2_final.csv"
output_file = "extra_genes.csv"
id_list_set = set(id_list)

csv_strings = {}
with open(csv_file, encoding="utf-8") as f:
    reader = csv.reader(f)
    for row in reader:
        if row:
            csv_strings[row[0].strip()] = row[1]
print(csv_strings)
in_def = []
for record in SeqIO.parse(gb_file, "genbank"):
    record_id_root = record.id.split(".")[0]
    if record_id_root not in id_list_set:
        continue
    definition = record.description
    if definition:
        def_lower = definition.lower()
        for csv_str in csv_strings:
            pattern = r"(?<!\w)" + re.escape(csv_str.lower()) + r"(?!\w)"
            if re.search(pattern, def_lower):
                in_def.append((record.id, csv_str, csv_strings[csv_str]))
                break
extra_genes = {}
for rec_id, match, gene in in_def:
    extra_genes[rec_id] = gene

with open(output_file, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["id", "gene"])
    for rec_id, gene in extra_genes.items():
        writer.writerow([rec_id, gene])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 id_list_set = set(id_list)
#       6 csv_strings = {}
# ----> 7 with open(csv_file, encoding="utf-8") as f:
#       8     reader = csv.reader(f)
#       9     for row in reader:
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '1ab_2_final.csv'

# %%
extra_genes
# Out:
# {'PX095696.1': '1B',
#  'PX113257.1': '2',
#  'PX113255.1': '1A',
#  'PV793827.1': '1A',
#  'PV793829.1': '1A',
#  'PV793828.1': '2',
#  'PV793826.1': '1A',
#  'PV793833.1': '1B',
#  'PV793831.1': '1B',
#  'PQ573797.1': '1A',
#  'PQ573796.1': '1A',
#  'PP272729.1': '1AB',
#  'OR951096.1': '1AB',
#  'OR951094.1': '1AB',
#  'OR951092.1': '1AB',
#  'OR951091.1': '1AB',
#  'OR951090.1': '1AB',
#  'OR951089.1': '1AB',
#  'OR951083.1': '1AB',
#  'OR951078.1': '1AB',
#  'OR951077.1': '1AB',
#  'OR951073.1': '1AB',
#  'OR951070.1': '1AB',
#  'OR951069.1': '1AB',
#  'OR951067.1': '1AB',
#  'OR951064.1': '1AB',
#  'OR951057.1': '1AB',
#  'OR951054.1': '1AB',
#  'OR951050.1': '1AB',
#  'OR951039.1': '1AB',
#  'OR951031.1': '1AB',
#  'OR951020.1': '1AB',
#  'OR951015.1': '1AB',
#  'OR951012.1': '1AB',
#  'OR951009.1': '1AB',
#  'OR951008.1': '1AB',
#  'OR800314.1': '1B',
#  'MW310482.1': '1B',
#  'MW310480.1': '1B',
#  'MW310478.1': '1B',
#  'MW310470.1': '1B',
#  'MW310467.1': '1B',
#  'MW310464.1': '1B',
#  'MW310462.1': '1B',
#  'OL739531.1': '1AB',
#  'MZ476779.1': '1B',
#  'MZ375144.1': '1AB',
#  'MW341109.1': '1B',
#  'MW341108.1': '1B',
#  'MW341107.1': '1B',
#  'MW341106.1': '1B',
#  'MW341105.1': '1B',
#  'MW341104.1': '1B',
#  'MW341103.1': '1B',
#  'MH325266.1': '1B',
#  'MH325265.1': '1B',
#  'MH325264.1': '1B',
#  'MH325263.1': '1B',
#  'MH325262.1': '1B',
#  'MH325261.1': '1B',
#  'MH325260.1': '1B',
#  'MH325259.1': '1B',
#  'MH325258.1': '1B',
#  'MH325257.1': '1B',
#  'MH325256.1': '1B',
#  'MH325255.1': '1B',
#  'MH325254.1': '1B',
#  'MH325253.1': '1B',
#  'MH325252.1': '1B',
#  'MH325251.1': '1B',
#  'MH325250.1': '1B',
#  'MH325249.1': '1B',
#  'MH325248.1': '1B',
#  'MH325247.1': '1B',
#  'MH325246.1': '1B',
#  'MH325245.1': '1B',
#  'MH325244.1': '1B',
#  'MH325243.1': '1B',
#  'MH325242.1': '1B',
#  'MH325241.1': '1B',
#  'MH325240.1': '1B',
#  'MH325239.1': '1B',
#  'MH325238.1': '1B',
#  'MH325237.1': '1B',
#  'MH325236.1': '1B',
#  'MH325235.1': '1B',
#  'MH325234.1': '1B',
#  'MH325233.1': '1B',
#  'MH325232.1': '1B',
#  'MH325231.1': '1B',
#  'MH325230.1': '1B',
#  'MH325229.1': '1B',
#  'MH325228.1': '1B',
#  'MH325227.1': '1B',
#  'MH325226.1': '1B',
#  'MH325225.1': '1B',
#  'MH325224.1': '1B',
#  'MH325223.1': '1B',
#  'MH325222.1': '1B',
#  'MH325221.1': '1B',
#  'MH325220.1': '1B',
#  'MH325219.1': '1B',
#  'MH325218.1': '1B',
#  'MH325217.1': '1B',
#  'MH325216.1': '1B',
#  'MH325215.1': '1B',
#  'MH325214.1': '1B',
#  'MH325213.1': '1B',
#  'MF973528.1': '1A',
#  'MF973527.1': '1A',
#  'MF973526.1': '1A',
#  'MF973525.1': '1A',
#  'MF973524.1': '1A',
#  'MF973523.1': '1A',
#  'MF973522.1': '1A',
#  'MF973521.1': '1A',
#  'MF973520.1': '1A',
#  'MF973519.1': '1A',
#  'MF973518.1': '1A',
#  'MF973517.1': '1A',
#  'MF973516.1': '1A',
#  'MF973515.1': '1A',
#  'MF973514.1': '1A',
#  'MF973513.1': '1A',
#  'MF973512.1': '1A',
#  'MF973511.1': '1A',
#  'MF973510.1': '1A',
#  'MF973509.1': '1A',
#  'MF973508.1': '1A',
#  'MF973507.1': '1A',
#  'MF973506.1': '1A',
#  'MF973505.1': '1A',
#  'MF973504.1': '1A',
#  'MF973503.1': '1A',
#  'MF973502.1': '1A',
#  'KU510484.1': '1B',
#  'KU510483.1': '1B',
#  'KU510482.1': '1B',
#  'KU510481.1': '1B',
#  'KU510480.1': '1B',
#  'KU510479.1': '1B',
#  'KU510478.1': '1B',
#  'KU510477.1': '1B',
#  'KU510476.1': '1B',
#  'KU510475.1': '1B',
#  'KU510474.1': '1B',
#  'KU510473.1': '1B',
#  'KU510472.1': '1B',
#  'KU510471.1': '1B',
#  'KU510470.1': '1B',
#  'KU510469.1': '1B',
#  'KU510468.1': '1B',
#  'KU510467.1': '1B',
#  'KU510466.1': '1B',
#  'KU510465.1': '1B',
#  'KU510464.1': '1B',
#  'KU510463.1': '1B',
#  'KU510462.1': '1B',
#  'KU510461.1': '1B',
#  'KU510460.1': '1B',
#  'KU510459.1': '1B',
#  'KU510458.1': '1B',
#  'KU510457.1': '1B',
#  'KU510456.1': '1B',
#  'KU510455.1': '1B',
#  'KU510454.1': '1B',
#  'KU510453.1': '1B',
#  'KU510452.1': '1B',
#  'KU510451.1': '1B',
#  'KU510450.1': '1B',
#  'KU510449.1': '1B',
#  'KU510448.1': '1B',
#  'KU510447.1': '1B',
#  'KU510446.1': '1B',
#  'KU510445.1': '1B',
#  'KU510444.1': '1B',
#  'KU510443.1': '1B',
#  'KU510442.1': '1B',
#  'KU510441.1': '1B',
#  'DQ066575.1': '2',
#  'DQ066559.1': '2',
#  'HQ623129.1': '2',
#  'HQ623126.1': '2',
#  'HM756267.1': '1B',
#  'HM756264.1': '1B',
#  'HM756263.1': '1B',
#  'GU216586.1': '2',
#  'AY027809.1': '1AB',
#  'KF211466.1': '2',
#  'KT852446.1': '1B',
#  'KT852439.1': '1B',
#  'KT852437.1': '1B',
#  'KT852436.1': '1B',
#  'KT852435.1': '1B',
#  'KT852434.1': '1B',
#  'KT852433.1': '1B',
#  'KT852432.1': '1B',
#  'KT852431.1': '1B',
#  'KT852430.1': '1B',
#  'KT852429.1': '1B',
#  'KT852428.1': '1B',
#  'KT852427.1': '1B',
#  'KT852426.1': '1B',
#  'KT852425.1': '1B',
#  'KT852424.1': '1B',
#  'KT852423.1': '1B',
#  'KT852422.1': '1B',
#  'KT852421.1': '1B',
#  'KT852420.1': '1B',
#  'KT852419.1': '1B',
#  'KT852418.1': '1B',
#  'KT852417.1': '1B',
#  'KT852416.1': '1B',
#  'KT852415.1': '1B',
#  'KT852414.1': '1B',
#  'KT852413.1': '1B',
#  'KT852412.1': '1B',
#  'KT852411.1': '1B',
#  'KT852410.1': '1B',
#  'KT852409.1': '1B',
#  'KT852408.1': '1B',
#  'KT852407.1': '1B',
#  'KT852406.1': '1B',
#  'KT852405.1': '1B',
#  'KT852404.1': '1B',
#  'KT852403.1': '1B',
#  'KT852402.1': '1B',
#  'KT852401.1': '1B',
#  'KT852400.1': '1B',
#  'KT852399.1': '1B',
#  'KT852398.1': '1B',
#  'KT852397.1': '1B',
#  'KT852396.1': '1B',
#  'KT852395.1': '1B',
#  'KT852394.1': '1B',
#  'KT852393.1': '1B',
#  'KT852392.1': '1B',
#  'KT852391.1': '1B',
#  'KT852390.1': '1B',
#  'KT852389.1': '1B',
#  'KT852388.1': '1B',
#  'KT852387.1': '1B',
#  'KT852386.1': '1B',
#  'KT852385.1': '1B',
#  'KT852384.1': '1B',
#  'KT852383.1': '1B',
#  'KT852382.1': '1B',
#  'KT852381.1': '1B',
#  'KT852380.1': '1B',
#  'KT852445.1': '1B',
#  'KT852444.1': '1B',
#  'KT852443.1': '1B',
#  'KT852442.1': '1B',
#  'KT852441.1': '1B',
#  'KT852440.1': '1B',
#  'KT852438.1': '1B',
#  'KT852448.1': '2',
#  'KT852447.1': '2',
#  'KM408171.1': '2',
#  'KM408170.1': '2',
#  'KR187145.1': '1B',
#  'KR138648.1': '1B',
#  'KR138620.1': '1B',
#  'KP162254.1': '1A',
#  'KP162253.1': '1A',
#  'KP162252.1': '1A',
#  'KP162251.1': '1A',
#  'KP162250.1': '1A',
#  'KP162249.1': '1A',
#  'KP162248.1': '1A',
#  'KC599256.1': '1B',
#  'KF920601.1': '1B',
#  'AB634860.1': '2',
#  'AB634859.1': '1B',
#  'AB634858.1': '2',
#  'AB634857.1': '1B',
#  'AB634856.1': '2',
#  'AB303400.1': '1A',
#  'AB303399.1': '1A',
#  'AB303398.1': '1A',
#  'AB303397.1': '1A',
#  'AB303396.1': '1A',
#  'AB303395.1': '1A',
#  'AB303394.1': '1A',
#  'AB299402.1': '1A',
#  'AB299401.1': '1A',
#  'AB299400.1': '1A',
#  'AB299399.1': '1A',
#  'AB299398.1': '1A',
#  'AB299397.1': '1A',
#  'AB299396.1': '1A',
#  'AB327186.1': '1A',
#  'HQ647383.1': '2',
#  'HQ647382.1': '1B',
#  'HQ647381.1': '1B',
#  'HQ662579.1': '1B',
#  'GU938474.1': '1B',
#  'GU938473.1': '1B',
#  'EF490429.1': '1A',
#  'FJ160481.1': '2',
#  'GQ174472.1': '2',
#  'GQ174471.1': '2',
#  'GQ174470.1': '2',
#  'GQ174469.1': '2',
#  'GQ174468.1': '2',
#  'GQ174467.1': '2',
#  'GQ174466.1': '2',
#  'GQ174465.1': '2',
#  'GQ174464.1': '2',
#  'GQ174463.1': '2',
#  'GQ174462.1': '2',
#  'GQ174461.1': '2',
#  'GQ174460.1': '2',
#  'GQ174459.1': '2',
#  'GQ174458.1': '2',
#  'GQ174457.1': '2',
#  'GQ174456.1': '2',
#  'GQ174455.1': '2',
#  'GQ174454.1': '2',
#  'GQ174453.1': '2',
#  'GQ174452.1': '2',
#  'GQ174451.1': '2',
#  'GQ174450.1': '2',
#  'GQ174449.1': '2',
#  'GQ174448.1': '2',
#  'GQ174447.1': '2',
#  'GQ174446.1': '2',
#  'GQ174445.1': '2',
#  'GQ174444.1': '2',
#  'GQ174443.1': '2',
#  'GQ174442.1': '2',
#  'GQ174441.1': '2',
#  'GQ174440.1': '2',
#  'GQ174439.1': '2',
#  'GU222334.1': '2',
#  'GU222333.1': '2',
#  'GU222332.1': '2',
#  'GU222331.1': '2',
#  'GU222330.1': '2',
#  'AY304452.1': '2',
#  'AY257977.1': '1A',
#  'AB211059.1': '1A',
#  'Z16420.1': '1AB'}

# %%
csv_str
# Out:
# 'virus capsid polyprotein'

# %% [markdown]
# Теперь проходимся по файлу AV_2.gb и в найденных idшниках добавляем product = gene

# %%
gb_file = "AV_2.gb"
extra_genes_file = "extra_genes.csv"
output_file = "AV_2_modified.gb"

extra_genes = {}
with open(extra_genes_file, encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        rec_id = row["id"].split('.')[0].strip()  # ID до точки
        gene = row["gene"].strip()
        extra_genes[rec_id] = gene

records = list(SeqIO.parse(gb_file, "genbank"))
for rec in records:
    rec_id_root = rec.id.split('.')[0]
    if rec_id_root in extra_genes:
        gene_name = extra_genes[rec_id_root]
        feature = SeqFeature(
            FeatureLocation(0, len(rec.seq)),
            type="CDS",
            qualifiers={"product": gene_name}
        )
        rec.features.append(feature)

SeqIO.write(records, output_file, "genbank")
# Out:
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109731, SAMN34109732, SAMN34109733, SAMN34109815, SAMN34109863' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113121, SRR24113120, SRR24113119, SRR24113058, SRR24113208' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109700, SAMN34109701, SAMN34109702, SAMN34109703, SAMN34109704' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113301, SRR24113300, SRR24113299, SRR24113298, SRR24113297' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109720, SAMN34109721, SAMN34109722, SAMN34109723, SAMN34109724' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113133, SRR24113132, SRR24113131, SRR24113130, SRR24113129' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109736, SAMN34109737, SAMN34109738, SAMN34109739, SAMN34109740' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113116, SRR24113115, SRR24113114, SRR24113113, SRR24113111' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109685, SAMN34109686, SAMN34109687, SAMN34109688, SAMN34109689' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113008, SRR24113007, SRR24113006, SRR24113005, SRR24113004' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109715, SAMN34109716, SAMN34109717, SAMN34109718, SAMN34109719' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113139, SRR24113138, SRR24113137, SRR24113136, SRR24113135' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109655, SAMN34109656, SAMN34109657, SAMN34109658, SAMN34109659' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113158, SRR24113157, SRR24113156, SRR24113155, SRR24113154' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109752, SAMN34109753, SAMN34109754, SAMN34109755, SAMN34109756' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113098, SRR24113097, SRR24113096, SRR24113095, SRR24113094' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109850, SAMN34109857, SAMN34109880, SAMN34109881, SAMN34109902' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113222, SRR24113215, SRR24113041, SRR24113040, SRR24113282' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109855, SAMN34109856, SAMN34109862, SAMN34109879, SAMN34109901' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113217, SRR24113216, SRR24113209, SRR24113043, SRR24113283' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109620, SAMN34109621, SAMN34109622, SAMN34109623, SAMN34109624' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113262, SRR24113134, SRR24113123, SRR24113112, SRR24113101' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109751, SAMN34109793, SAMN34109794, SAMN34109795, SAMN34109796' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113099, SRR24113083, SRR24113082, SRR24113081, SRR24113080' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113198, SRR24113176, SRR24113314, SRR24113313' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109650, SAMN34109651, SAMN34109652, SAMN34109653, SAMN34109654' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113163, SRR24113162, SRR24113161, SRR24113160, SRR24113159' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109665, SAMN34109666, SAMN34109667, SAMN34109668, SAMN34109669' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113147, SRR24113146, SRR24113145, SRR24113144, SRR24113026' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109670, SAMN34109671, SAMN34109672, SAMN34109673, SAMN34109674' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113024, SRR24113023, SRR24113022, SRR24113021, SRR24113020' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109675, SAMN34109676, SAMN34109677, SAMN34109678, SAMN34109679' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113019, SRR24113018, SRR24113017, SRR24113016, SRR24113015' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109746, SAMN34109747, SAMN34109748, SAMN34109749, SAMN34109750' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113105, SRR24113104, SRR24113103, SRR24113102, SRR24113100' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109849, SAMN34109871, SAMN34109895, SAMN34109950, SAMN34109959' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113224, SRR24113051, SRR24113290, SRR24113325, SRR24113316' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109810, SAMN34109811, SAMN34109812, SAMN34109813, SAMN34109814' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113063, SRR24113062, SRR24113061, SRR24113060, SRR24113059' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109846, SAMN34109909, SAMN34109948, SAMN34109957, SAMN34109966' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113227, SRR24113275, SRR24113328, SRR24113318, SRR24113308' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109615, SAMN34109616, SAMN34109617, SAMN34109618, SAMN34109619' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113153, SRR24113025, SRR24113014, SRR24113003, SRR24113302' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109635, SAMN34109636, SAMN34109637, SAMN34109638, SAMN34109639' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113212, SRR24113053, SRR24113042, SRR24113031, SRR24113285' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109625, SAMN34109626, SAMN34109627, SAMN34109628, SAMN34109629' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113090, SRR24113255, SRR24113244, SRR24113233, SRR24113076' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109773, SAMN34109774, SAMN34109816, SAMN34109817, SAMN34109818' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113251, SRR24113250, SRR24113057, SRR24113056, SRR24113055' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109845, SAMN34109858, SAMN34109866, SAMN34109888, SAMN34109945' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113228, SRR24113214, SRR24113205, SRR24113033, SRR24113331' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN34109844, SAMN34109887, SAMN34109922, SAMN34109923, SAMN34109944' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR24113229, SRR24113034, SRR24113197, SRR24113196, SRR24113332' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN24043624, SAMN24043627, SAMN24043630, SAMN24043633, SAMN24043634' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR17243415, SRR17243412, SRR17243422, SRR17243419, SRR17243418' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'BioSample: SAMN27590737, SAMN27590738, SAMN27590739, SAMN27590740, SAMN27590741, SAMN27590742, SAMN27590743, SAMN27590744, SAMN27590745, SAMN27590746, SAMN27590747' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR18765324, SRR18765325, SRR18765326, SRR18765327, SRR18765328, SRR18765329, SRR18765330, SRR18765331, SRR18765332, SRR18765333, SRR18765334' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR15533023, SRR15533047, SRR15533062, SRR15533071, SRR15573089, SRR15533106, SRR15533078' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# C:\Python310\lib\site-packages\Bio\SeqIO\InsdcIO.py:600: BiopythonWarning: Annotation 'Sequence Read Archive: SRR15186924, SRR15186925, SRR15186926, SRR15186927, SRR15186928, SRR15186929, SRR15186930, SRR15186931, SRR15186932, SRR15186933, SRR15186934, SRR15186935, SRR15186936, SRR15186937, SRR15186938, SRR15186939, SRR15186940, SRR15186941, SRR15186942, SRR15186943, SRR15186944, SRR15186945, SRR15186946, SRR15186947, SRR15186948, SRR15186950, SRR15186952, SRR15186953, SRR15186954, SRR15186955, SRR15186956, SRR15186957, SRR15186958, SRR15186959, SRR15186960, SRR15186961, SRR15186962, SRR15186963, SRR15186964, SRR15186965, SRR15186966, SRR15186968, SRR15186969, SRR15186970, SRR15186971, SRR15186972, SRR15186973, SRR15186974, SRR15186975, SRR15186976, SRR15186977, SRR15186978, SRR15186979, SRR15186980, SRR15186981, SRR15186984, SRR15186985, SRR15186986, SRR15186987, SRR15186988, SRR15186989, SRR15186990, SRR15186991, SRR15186992, SRR15186993, SRR15186994, SRR15186995, SRR15186996, SRR15186997, SRR15186999, SRR15187001, SRR15187002, SRR15187003, SRR15187004, SRR15187005, SRR15187006, SRR15187007, SRR15187008, SRR15187009, SRR15187010, SRR15187011, SRR15187012, SRR15187014, SRR15187015, SRR15187016, SRR15187017, SRR15187018, SRR15187019, SRR15187020, SRR15187021, SRR15187022, SRR15187023, SRR15187024, SRR15187025, SRR15186949, SRR15186951, SRR15186967, SRR15186982, SRR15186983, SRR15186998, SRR15187000, SRR15187013' too long
#   warnings.warn(f"Annotation {text!r} too long", BiopythonWarning)
# 15566

# %% [markdown]
# Вытаскиваю айдишники с пустыми координатами, несмотря на все манипуляции выше

# %%
import pandas as pd
df = pd.read_csv("AV_2_modified_orf.txt")
result = df[(df["1A"] == "NA-NA") &Y08632 (df["1B"] == "NA-NA") & (df["2"] == "NA-NA")]
id_list_modified = result["id"].tolist()
print(len(id_list_modified))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 df = pd.read_csv("AV_2_modified_orf.txt")
# ----> 3 result = df[(df["1A"] == "NA-NA") &Y08632 (df["1B"] == "NA-NA") & (df["2"] == "NA-NA")]
#       4 id_list_modified = result["id"].tolist()
#       5 print(len(id_list_modified))
#
# NameError: name 'Y08632' is not defined
